# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import cv2 as cv

# %%
img = cv.imread('DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img = cv.imread('asikdjaiosujdioajisd')

# %%
type(img)
# Out:
# NoneType

# %%
img = cv.imread('DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
fix_img = cv.cvtColor(img, cv.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv.imread('DATA/00-puppy.jpg', cv.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv.resize(fix_img,(1000, 400))

# %%
plt.imshow(new_img)

# %%
new_img.shape
# Out:
# (400, 1000, 3)

# %%
fix_new_img = cv.resize(fix_img,(0,0),fix_img, 0.5, 0.5)

# %%
plt.imshow(fix_new_img)

# %%
fix_new_img.shape
# Out:
# (650, 975, 3)

# %%
fix_new_img = cv.flip(fix_new_img, 0)

# %%
plt.imshow(fix_new_img)

# %%
cv.imwrite('total_new_img.jpg', fix_new_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(2,2))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
